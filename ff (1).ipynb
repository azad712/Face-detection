# %%
# I import libraries that I will use.(Kullanacağım kütüphaneleri import ediyorum.)
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# For preparing (Hazırlık için)
import xml.etree.cElementTree as ET
import glob
import os
import json
import random
import shutil

from PIL import Image, ImageOps

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
import yaml#

# Load the YAML file
#file_path = 'data5.yaml'
file_path = "/root/.config/Ultralytics/settings.yaml"

with open(file_path, 'r') as yaml_file:
    config = yaml.load(yaml_file, Loader=yaml.FullLoader)

config['datasets_dir'] = ''
#print(config['datasets_dir'])
#print(config)

'''
# Modify the paths in the configuration
# For example, assuming there's a path in the 'data_path' key
new_train_path = '/content/datasets/facefirst/train/images'
new_valid_path = '/content/datasets/facefirst/valid/images'
new_test_path = '/content/datasets/facefirst/test/images'
config['train'] = new_train_path
config['val'] = new_valid_path
config['test'] = new_test_path

# Save the modified configuration back to the YAML file
with open(file_path, 'w') as yaml_file:
    yaml.dump(config, yaml_file, default_flow_style=False)

print("YAML file has been updated.")

new_config_path = '/content/datasets/facefirst/destdir'
config['datasets_dir'] = new_config_path
'''
#Save the modified configuration back to the YAML file
with open(file_path, 'w') as yaml_file:
    yaml.dump(config, yaml_file, default_flow_style=False)

print("YAML file has been updated.")
# Out:
# YAML file has been updated.

# %%
# %pip install ultralytics
import ultralytics
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.0.209 🚀 Python-3.10.12 torch-2.1.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 26.7/78.2 GB disk)

# %%
from ultralytics import YOLO

# Create a new YOLO model from scratch
#model = YOLO('yolov8n.yaml')

# Load a pretrained YOLO model (recommended for training)
model = YOLO('yolov8n.pt')

# Train the model using the 'coco128.yaml' dataset for 3 epochs
# Out:
# ...
# 100%|██████████| 6.23M/6.23M [00:00<00:00, 322MB/s]

# %%
# List files in the root directory of your Google Drive.

# !ls gdrive/MyDrive/facefirst/
# Out:
# data.yaml  README.dataset.txt  README.roboflow.txt  test  train  valid

# %%
# Train YOLOv8n on COCO8 for 3 epochs
# !yolo train model=yolov8n.pt data= gdrive/MyDrive/facefirst/data.yaml epochs=200 imgsz=640  conf=0.90
# Out:
# Ultralytics YOLOv8.0.209 🚀 Python-3.10.12 torch-2.1.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
import yaml

# Load the YAML file
file_path = 'gdrive/MyDrive/facefirst/data.yaml'

with open(file_path, 'r') as yaml_file:
    config = yaml.load(yaml_file, Loader=yaml.FullLoader)

# Modify the paths in the configuration
# For example, assuming there's a path in the 'data_path' key

new_train_path = 'gdrive/MyDrive/facefirst/train/images'
new_valid_path = 'gdrive/MyDrive/facefirst/valid/images'
new_test_path = 'gdrive/MyDrive/facefirst/test/images'
config['train'] = new_train_path
config['val'] = new_valid_path
config['test'] = new_test_path

# Save the modified configuration back to the YAML file
with open(file_path, 'w') as yaml_file:
    yaml.dump(config, yaml_file, default_flow_style=False)
